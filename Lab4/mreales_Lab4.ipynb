# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736 =
# (x-4)(x-7)(x-62)(x**7+1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736

p, r = div(p,  x-1)

print(p)
print(r)

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)

p, r = div(p,  x-4)

print(p)
print(r)
# Out:
# x**9 - 72*x**8 + 638*x**7 - 1098*x**6 - 1098*x**5 - 1098*x**4 - 1098*x**3 - 1097*x**2 - 1170*x - 460
# -2196
# x**8 - 70*x**7 + 498*x**6 - 102*x**5 - 1302*x**4 - 3702*x**3 - 8502*x**2 - 18101*x - 37372
# -75204
# x**7 - 67*x**6 + 297*x**5 + 789*x**4 + 1065*x**3 - 507*x**2 - 10023*x - 48170
# -181882
# x**6 - 63*x**5 + 45*x**4 + 969*x**3 + 4941*x**2 + 19257*x + 67005
# 219850

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p = x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736

p, r = div(p,  x-6)

print(p)
print(r)
# Out:
# x**9 - 67*x**8 + 308*x**7 + 112*x**6 + 672*x**5 + 4032*x**4 + 24192*x**3 + 145153*x**2 + 870845*x + 5225780
# 31352944

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736)
# Out:
# (x - 62)*(x - 7)*(x - 4)*(x + 1)*(x**6 - x**5 + x**4 - x**3 + x**2 - x + 1)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# -x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736, 0), x)
# Out:
# {-1, 4, 7, 62, cos(pi/7) - I*sin(pi/7), cos(pi/7) + I*sin(pi/7), -cos(2*pi/7) - I*sin(2*pi/7), -cos(2*pi/7) + I*sin(2*pi/7), cos(3*pi/7) - I*sin(3*pi/7), cos(3*pi/7) + I*sin(3*pi/7)}

# %%
import sympy as sp

# Definir la variable simbólica x
x = sp.symbols('x')
# Definir la ecuación cuadrática
eq = x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736
# Encontrar las soluciones de la ecuación cuadrática
sol = sp.solveset(eq, x)
# Imprimir las soluciones
print("Las soluciones de la ecuación son: ", sol)
# Out:
# Las soluciones de la ecuación son:  {-1, 4, 7, 62, cos(pi/7) - I*sin(pi/7), cos(pi/7) + I*sin(pi/7), -cos(2*pi/7) - I*sin(2*pi/7), -cos(2*pi/7) + I*sin(2*pi/7), cos(3*pi/7) - I*sin(3*pi/7), cos(3*pi/7) + I*sin(3*pi/7)}

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736 , 0), x)
# Out:
# {-1, 4, 7, 62, cos(pi/7) - I*sin(pi/7), cos(pi/7) + I*sin(pi/7), -cos(2*pi/7) - I*sin(2*pi/7), -cos(2*pi/7) + I*sin(2*pi/7), cos(3*pi/7) - I*sin(3*pi/7), cos(3*pi/7) + I*sin(3*pi/7)}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(sqrt(2)*x**3-pi*x**2+sqrt(2)*x , 0), x)
# Out:
# {0, -sqrt(2)*sqrt(-8 + pi**2)/4 + sqrt(2)*pi/4, sqrt(2)*sqrt(-8 + pi**2)/4 + sqrt(2)*pi/4}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736 ,domain='GF(3)')
# Out:
# (x - 1)**2*(x + 1)**2*(x**6 - x**5 + x**4 - x**3 + x**2 - x + 1)

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = 2+3*I
y = -4-2*I
z = 1+2*I

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (-4 - 2*I)*(1 + 2*I)*(2 + 3*I)
# 30 - 20*I
# 30 - 20*I
# 30 - 20*I
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - what is the schedule for this year?
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736, x)
# Out:
# x**11/11 - 73*x**10/10 + 710*x**9/9 - 217*x**8 + x**4/4 - 73*x**3/3 + 355*x**2 - 1736*x

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736, (x,1,5))
# Out:
# 1219162256/495

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**10-73*x**9+710*x**8-1736*x**7+x**3-73*x**2+710*x-1736, (x,1,5)))
# Out:
# 2462954.05252525
